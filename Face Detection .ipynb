# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
classfier=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
black  = cv2.COLOR_BGR2RGB 
gray = cv2.COLOR_BGR2GRAY

# %%
img1=cv2.imread('cs50.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,10))
plt.imshow(img1)

# %%
grayimg=cv2.cvtColor(img1,cv2.COLOR_RGB2GRAY)

# %%
faces=classfier.detectMultiScale(grayimg,scaleFactor=1.1,minNeighbors=5,minSize=(20,20))

# %%
print(faces)
# Out:
# [[1216  373   75   75]
#  [ 219  378   69   69]
#  [ 372  379   71   71]
#  [ 695  424   64   64]
#  [1565  403   72   72]
#  [  40  407   68   68]
#  [1110  425   73   73]
#  [1276  432   71   71]
#  [1439  438   72   72]
#  [ 222  446   74   74]
#  [ 635  459   66   66]
#  [ 263  501  104  104]
#  [ 975  497   66   66]
#  [1607  471   66   66]
#  [ 523  480   70   70]
#  [  86  496   68   68]
#  [ 137  492   89   89]
#  [ 448  499   82   82]
#  [ 705  501   77   77]
#  [ 349  505   82   82]
#  [ 137  597  112  112]
#  [ 907  536   69   69]
#  [1908  533   74   74]
#  [1704  543   73   73]
#  [ 847  549   62   62]
#  [1498  543   86   86]
#  [   2  540   91   91]
#  [1014  571   66   66]
#  [1797  545   87   87]
#  [ 596  558   82   82]
#  [1620  573   79   79]
#  [1147  576   78   78]
#  [1330  588   75   75]
#  [ 572  636   87   87]
#  [ 449  635   95   95]
#  [  66  728  120  120]
#  [1554  766  100  100]
#  [ 834  697   57   57]
#  [ 720  812  115  115]
#  [ 968  793   90   90]
# ...

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(img1,(x,y),(x+w,y+h),color=(255,0,0),thickness=5)
RGB_img=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
